# %%
import numpy as np
import pandas as pd
import matplotlib as py

# %%
boston_data = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/Boston_Housing/Training_set_boston.csv")

# %%
boston_data.head(5)
# Out:
#        CRIM    ZN  INDUS  CHAS     NOX     RM   AGE     DIS   RAD    TAX  \
# 0  15.02340   0.0  18.10   0.0  0.6140  5.304  97.3  2.1007  24.0  666.0
# 1   0.62739   0.0   8.14   0.0  0.5380  5.834  56.5  4.4986   4.0  307.0
# 2   0.03466  35.0   6.06   0.0  0.4379  6.031  23.3  6.6407   1.0  304.0
# 3   7.05042   0.0  18.10   0.0  0.6140  6.103  85.1  2.0218  24.0  666.0
# 4   0.72580   0.0   8.14   0.0  0.5380  5.727  69.5  3.7965   4.0  307.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     20.2  349.48  24.91  12.0
# 1     21.0  395.62   8.47  19.9
# 2     16.9  362.25   7.83  19.4
# 3     20.2    2.52  23.29  13.4
# 4     21.0  390.95  11.28  18.2

# %%
boston_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404 entries, 0 to 403
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     404 non-null    float64
#  1   ZN       404 non-null    float64
#  2   INDUS    404 non-null    float64
#  3   CHAS     404 non-null    float64
#  4   NOX      404 non-null    float64
#  5   RM       404 non-null    float64
#  6   AGE      404 non-null    float64
#  7   DIS      404 non-null    float64
#  8   RAD      404 non-null    float64
#  9   TAX      404 non-null    float64
#  10  PTRATIO  404 non-null    float64
#  11  B        404 non-null    float64
#  12  LSTAT    404 non-null    float64
#  13  MEDV     404 non-null    float64
# dtypes: float64(14)
# memory usage: 44.3 KB

# %%
boston_data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     3.609125   11.569307   10.985050    0.071782    0.556484    6.315891
# std      8.875058   23.152481    6.894618    0.258447    0.117704    0.709452
# min      0.009060    0.000000    0.740000    0.000000    0.385000    3.863000
# 25%      0.081437    0.000000    5.130000    0.000000    0.452000    5.890500
# 50%      0.261390    0.000000    8.560000    0.000000    0.538000    6.210000
# 75%      3.202962   20.000000   18.100000    0.000000    0.631000    6.636750
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    68.556436    3.808195    9.356436  404.032178   18.318317  356.278342
# ...

# %%
x = boston_data.drop("MEDV", axis = 1)
y = boston_data.MEDV

# %%
x
# Out:
#          CRIM    ZN  INDUS  CHAS     NOX     RM   AGE     DIS   RAD    TAX  \
# 0    15.02340   0.0  18.10   0.0  0.6140  5.304  97.3  2.1007  24.0  666.0
# 1     0.62739   0.0   8.14   0.0  0.5380  5.834  56.5  4.4986   4.0  307.0
# 2     0.03466  35.0   6.06   0.0  0.4379  6.031  23.3  6.6407   1.0  304.0
# 3     7.05042   0.0  18.10   0.0  0.6140  6.103  85.1  2.0218  24.0  666.0
# 4     0.72580   0.0   8.14   0.0  0.5380  5.727  69.5  3.7965   4.0  307.0
# ..        ...   ...    ...   ...     ...    ...   ...     ...   ...    ...
# 399   0.17120   0.0   8.56   0.0  0.5200  5.836  91.9  2.2110   5.0  384.0
# 400   0.29916  20.0   6.96   0.0  0.4640  5.856  42.1  4.4290   3.0  223.0
# 401   0.01501  80.0   2.01   0.0  0.4350  6.635  29.7  8.3440   4.0  280.0
# 402  11.16040   0.0  18.10   0.0  0.7400  6.629  94.6  2.1247  24.0  666.0
# 403   0.22876   0.0   8.56   0.0  0.5200  6.405  85.4  2.7147   5.0  384.0
#
#      PTRATIO       B  LSTAT
# 0       20.2  349.48  24.91
# ...

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
features = x_train.shape[1]
print(features)
# Out:
# 13

# %%
x_train.shape
# Out:
# (323, 13)

# %% [markdown]
# #Training the model

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from numpy.random import seed
import tensorflow

# %%
model = Sequential()
model.add(Dense(10, activation = 'relu', input_shape = (features,)))
model.add(Dense(8, activation = 'relu', input_shape = (features,)))
model.add(Dense(1))

# %%
from tensorflow.keras.optimizers import RMSprop
optimizer = RMSprop(0.01)

# %%
model.compile(loss = "mean_squared_error", optimizer=optimizer)

# %%
seed_value = 42
seed(seed_value) # If you build the model with given parameters, set_random_seed will help you produce the same result on multiple execution


# Recommended by Keras -------------------------------------------------------------------------------------
# 1. Set `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)

# 3. Set `numpy` pseudo-random generator at a fixed value
import numpy as np
np.random.seed(seed_value)
# Recommended by Keras -------------------------------------------------------------------------------------


# 4. Set the `tensorflow` pseudo-random generator at a fixed value
tensorflow.random.set_seed(seed_value)
model.fit(X_train, y_train, epochs=10, batch_size=30, verbose = 1) # fit the model
# Out:
# Epoch 1/10
# 11/11 [==============================] - 1s 7ms/step - loss: 3424.8242
# Epoch 2/10
# 11/11 [==============================] - 0s 3ms/step - loss: 175.0317
# Epoch 3/10
# 11/11 [==============================] - 0s 3ms/step - loss: 166.0612
# Epoch 4/10
# 11/11 [==============================] - 0s 3ms/step - loss: 174.9949
# Epoch 5/10
# 11/11 [==============================] - 0s 3ms/step - loss: 101.8015
# Epoch 6/10
# 11/11 [==============================] - 0s 7ms/step - loss: 192.2431
# Epoch 7/10
# 11/11 [==============================] - 0s 4ms/step - loss: 116.4234
# Epoch 8/10
# 11/11 [==============================] - 0s 5ms/step - loss: 128.7848
# Epoch 9/10
# 11/11 [==============================] - 0s 3ms/step - loss: 127.7806
# Epoch 10/10
# 11/11 [==============================] - 0s 3ms/step - loss: 115.8689

# %%
model.evaluate(X_test,  y_test)
# Out:
# 3/3 [==============================] - 0s 4ms/step - loss: 59.6878
# 59.68782043457031

# %% [markdown]
# #Hyperparameter Tuning

# %% [markdown]
# Adjust learning rate

# %%
model = Sequential()
model.add(Dense(10, activation = 'relu', input_shape = (features,)))
model.add(Dense(8, activation = 'relu', input_shape = (features,)))
model.add(Dense(1))
from tensorflow.keras.optimizers import RMSprop
optimizer = RMSprop(0.001)
model.compile(loss = "mean_squared_error", optimizer=optimizer)
model.fit(X_train, y_train, epochs=10, batch_size=30, verbose = 1) # fit the model
model.evaluate(X_test,  y_test)
# Out:
# Epoch 1/10
# 11/11 [==============================] - 1s 2ms/step - loss: 192.7825
# Epoch 2/10
# 11/11 [==============================] - 0s 2ms/step - loss: 103.5376
# Epoch 3/10
# 11/11 [==============================] - 0s 2ms/step - loss: 90.8591
# Epoch 4/10
# 11/11 [==============================] - 0s 2ms/step - loss: 85.2131
# Epoch 5/10
# 11/11 [==============================] - 0s 2ms/step - loss: 80.9735
# Epoch 6/10
# 11/11 [==============================] - 0s 2ms/step - loss: 79.7044
# Epoch 7/10
# 11/11 [==============================] - 0s 3ms/step - loss: 78.0321
# Epoch 8/10
# 11/11 [==============================] - 0s 2ms/step - loss: 76.9448
# Epoch 9/10
# 11/11 [==============================] - 0s 2ms/step - loss: 75.6264
# Epoch 10/10
# 11/11 [==============================] - 0s 2ms/step - loss: 75.6339
# ...

# %%
model = Sequential()
model.add(Dense(10, activation = 'relu', input_shape = (features,)))
model.add(Dense(8, activation = 'relu', input_shape = (features,)))
model.add(Dense(1))
from tensorflow.keras.optimizers import RMSprop
optimizer = RMSprop(0.001)
epochs = 45
model.compile(loss = "mean_squared_error", optimizer=optimizer)
model.fit(X_train, y_train, epochs=epochs, batch_size=30, verbose = 1) # fit the model
model.evaluate(X_test,  y_test)
# Out:
# Epoch 1/45
# 11/11 [==============================] - 1s 2ms/step - loss: 281.4617
# Epoch 2/45
# 11/11 [==============================] - 0s 2ms/step - loss: 173.6276
# Epoch 3/45
# 11/11 [==============================] - 0s 2ms/step - loss: 138.0988
# Epoch 4/45
# 11/11 [==============================] - 0s 2ms/step - loss: 123.0755
# Epoch 5/45
# 11/11 [==============================] - 0s 2ms/step - loss: 114.0053
# Epoch 6/45
# 11/11 [==============================] - 0s 2ms/step - loss: 107.8220
# Epoch 7/45
# 11/11 [==============================] - 0s 2ms/step - loss: 102.4205
# Epoch 8/45
# 11/11 [==============================] - 0s 2ms/step - loss: 98.1735
# Epoch 9/45
# 11/11 [==============================] - 0s 2ms/step - loss: 94.6693
# Epoch 10/45
# 11/11 [==============================] - 0s 2ms/step - loss: 90.5067
# Epoch 11/45
# 11/11 [==============================] - 0s 2ms/step - loss: 86.4929
# Epoch 12/45
# ...

# %%
model = Sequential()
model.add(Dense(10, activation = 'relu', input_shape = (features,)))
model.add(Dense(8, activation = 'relu', input_shape = (features,)))
model.add(Dense(1))
from tensorflow.keras.optimizers import RMSprop
Learning_rate = 0.01
optimizer = RMSprop(Learning_rate)
epochs = 45

model.compile(loss = "mean_squared_error", optimizer=optimizer)
model.fit(X_train, y_train, epochs=epochs, batch_size=30, verbose = 1) # fit the model
model.evaluate(X_test,  y_test)
# Out:
# Epoch 1/45
# 11/11 [==============================] - 1s 2ms/step - loss: 549.9697
# Epoch 2/45
# 11/11 [==============================] - 0s 2ms/step - loss: 123.6556
# Epoch 3/45
# 11/11 [==============================] - 0s 2ms/step - loss: 120.1864
# Epoch 4/45
# 11/11 [==============================] - 0s 3ms/step - loss: 116.0835
# Epoch 5/45
# 11/11 [==============================] - 0s 2ms/step - loss: 101.5782
# Epoch 6/45
# 11/11 [==============================] - 0s 2ms/step - loss: 105.3995
# Epoch 7/45
# 11/11 [==============================] - 0s 2ms/step - loss: 107.3407
# Epoch 8/45
# 11/11 [==============================] - 0s 2ms/step - loss: 102.0830
# Epoch 9/45
# 11/11 [==============================] - 0s 2ms/step - loss: 71.2367
# Epoch 10/45
# 11/11 [==============================] - 0s 2ms/step - loss: 96.2992
# Epoch 11/45
# 11/11 [==============================] - 0s 2ms/step - loss: 74.8872
# Epoch 12/45
# ...

# %% [markdown]
# Training loss should steadily decrease, steeply at first, and then more slowly until the slope of the curve reaches or approaches zero.
# If the training loss does not converge, train for more epochs.
# If the training loss decreases too slowly, increase the learning rate. Note that setting the learning rate too high may also prevent training loss from converging.
# If the training loss varies wildly (that is, the training loss jumps around), decrease the learning rate.
# Lowering the learning rate while increasing the number of epochs or the batch size is often a good combination.
# Setting the batch size to a very small batch number can also cause instability. First, try large batch size values. Then, decrease the batch size until you see degradation.
# For real-world datasets consisting of a very large number of examples, the entire dataset might not fit into memory. In such cases, you'll need to reduce the batch size to enable a batch to fit into memory.
# Remember: the ideal combination of hyperparameters is data dependent, so you must always experiment and verify.

# %%
test = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/Boston_Housing/Testing_set_boston.csv")

# %%
model.predict(test)
# Out:
# array([[24.226982 ],
#        [25.137524 ],
#        [15.827255 ],
#        [21.181791 ],
#        [15.446242 ],
#        [20.12325  ],
#        [16.428774 ],
#        [12.793966 ],
#        [19.044825 ],
#        [21.093689 ],
#        [17.809233 ],
#        [17.744955 ],
#        [11.12262  ],
#        [19.081604 ],
#        [20.227991 ],
#        [18.01637  ],
#        [13.252092 ],
#        [ 8.233999 ],
#        [32.7454   ],
#        [15.073683 ],
#        [20.454363 ],
#        [21.896063 ],
#        [12.200258 ],
#        [20.73227  ],
#        [14.922433 ],
#        [13.820247 ],
#        [20.777922 ],
#        [10.110424 ],
#        [18.179995 ],
#        [20.680983 ],
#        [20.710081 ],
#        [22.876623 ],
#        [17.117727 ],
#        [20.46308  ],
#        [12.910735 ],
#        [ 9.997993 ],
#        [23.808609 ],
#        [19.31512  ],
#        [17.802338 ],
#        [19.06491  ],
#        [15.912777 ],
#        [32.1868   ],
#        [37.261295 ],
# ...
